# %%
from src.ipython_array_animation import AnimateArray
import numpy as np

# %%
AnimateArray([
    np.random.rand(30),
    np.random.rand(30),
    np.random.rand(30),
    np.random.rand(30),
    np.random.rand(30),
]).show()
# Out:
# <div id="4619389448">
# </div>
# <script type="text/javascript">
# (function() {
#     var id = '4619389448'
# ...

# %%
AnimateArray([
    np.random.rand(10, 10),
    np.random.rand(10, 10),
    np.random.rand(10, 10),
    np.random.rand(10, 10),
    np.random.rand(10, 10),
], cmap='prism').show()
# Out:
# <div id="4619390600">
# </div>
# <script type="text/javascript">
# (function() {
#     var id = '4619390600'
# ...
